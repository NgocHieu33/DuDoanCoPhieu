# %%
import pandas as pd #đọc dữ liệu
import numpy as np #xử lý dữ liệu
import matplotlib.pyplot as plt #vẽ biểu đồ
from sklearn.preprocessing import MinMaxScaler
from keras.callbacks import ModelCheckpoint #lưu lại huấn luyện tốt nhất
from tensorflow.keras.models import load_model #tải mô hình

#các lớp để xây dựng mô hình
from keras.models import Sequential #đầu vào
from keras.layers import LSTM #học phụ thuộc
from keras.layers import Dropout #tránh học tủ
from keras.layers import Dense #đầu ra

#kiểm tra độ chính xác của mô hình
from sklearn.metrics import r2_score #đo mức độ phù hợp
from sklearn.metrics import mean_absolute_error #đo sai số tuyệt đối trung bình
from sklearn.metrics import mean_absolute_percentage_error #đo % sai số tuyệt đối trung bình
from scipy.interpolate import interp1d

# %%
#tạo quyền truy cập với google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# đọc dữ liệu từ file csv
df = pd.read_csv('/content/drive/MyDrive/dataset/test6.csv')

# Hiển thị lại DataFrame sau khi xóa
print(df)
# Out:
#   Thoi gian     Mua   Chi so DO
# 0  Nam 2017  Mua kho         89
# 1       NaN  Mua mua         78
# 2  Nam 2018  Mua kho         97
# 3       NaN  Mua mua         70
# 4  Nam 2019  Mua kho         85
# 5       NaN  Mua mua         87
# 6  Nam 2020  Mua kho        100
# 7       NaN  Mua mua         55
# 8  Nam 2022  Mua kho         71
# 9       NaN  Mua mua         79

# %%
#kích thước dữ liệu
df.shape
# Out:
# (10, 3)

# %%
#xác định kiểu dữ liệu
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Thoi gian  5 non-null      object
#  1   Mua        10 non-null     object
#  2   Chi so DO  10 non-null     int64
# dtypes: int64(1), object(2)
# memory usage: 368.0+ bytes

# %%
#mô tả bộ dữ liệu
df.describe()
# Out:
#         Chi so DO
# count   10.000000
# mean    81.100000
# std     13.510901
# min     55.000000
# 25%     72.750000
# 50%     82.000000
# 75%     88.500000
# max    100.000000

# %%
# Tạo DataFrame từ dữ liệu mẫu
data = {
    'Thoi gian': [
        'Nam 2017 mua kho', 'Nam 2017 mua mua',
        'Nam 2018 mua kho', 'Nam 2018 mua mua',
        'Nam 2019 mua kho', 'Nam 2019 mua mua',
        'Nam 2020 mua kho', 'Nam 2020 mua mua',
        'Nam 2022 mua kho', 'Nam 2022 mua mua'
    ],
    'Chi so DO': [88, 77, 98, 70, 86, 71, 73, 85, 68, 74]
}
df = pd.DataFrame(data)

# Tạo cột 'Nam' và 'Mua' bằng cách tách chuỗi trong cột 'Thoi gian'
df[['Nam', 'Mua']] = df['Thoi gian'].str.extract(r'(Nam \d+)\s*(mua \w+)', expand=True)

# Xử lý các giá trị NaN bằng cách loại bỏ các hàng chứa giá trị NaN
df.dropna(subset=['Nam', 'Mua'], inplace=True)

# Chuyển đổi cột 'Nam' thành kiểu số nguyên
df['Nam'] = df['Nam'].str.extract(r'(\d+)').astype(int)

# Hiển thị lại DataFrame sau khi tạo các cột mới và loại bỏ các giá trị NaN
print(df)
# Vẽ biểu đồ WQI của từng năm có hai mùa 'mua kho' và 'mua mua'
plt.figure(figsize=(12, 8))

# Tách dữ liệu theo mùa
df_mua_kho = df[df['Mua'] == 'mua kho']
df_mua_mua = df[df['Mua'] == 'mua mua']

# Vẽ đường cho mùa khô
plt.plot(df_mua_kho['Nam'], df_mua_kho['Chi so DO'], marker='o', linestyle='-', color='b', label='Mùa khô')

# Vẽ đường cho mùa mưa
plt.plot(df_mua_mua['Nam'], df_mua_mua['Chi so DO'], marker='o', linestyle='-', color='g', label='Mùa mưa')

plt.xlabel('Năm')
plt.ylabel('DO')
plt.title('Biểu đồ DO của từng năm theo mùa')
plt.legend()
plt.grid(True)
plt.xticks(df['Nam'].unique())
plt.tight_layout()
plt.show()
# Out:
#           Thoi gian  Chi so DO   Nam      Mua
# 0  Nam 2017 mua kho         88  2017  mua kho
# 1  Nam 2017 mua mua         77  2017  mua mua
# 2  Nam 2018 mua kho         98  2018  mua kho
# 3  Nam 2018 mua mua         70  2018  mua mua
# 4  Nam 2019 mua kho         86  2019  mua kho
# 5  Nam 2019 mua mua         71  2019  mua mua
# 6  Nam 2020 mua kho         73  2020  mua kho
# 7  Nam 2020 mua mua         85  2020  mua mua
# 8  Nam 2022 mua kho         68  2022  mua kho
# 9  Nam 2022 mua mua         74  2022  mua mua

# %%
# Tạo một DataFrame mới chỉ chứa các cột 'Thoi gian' và 'WQI tong'
df1 = pd.DataFrame(df, columns=['Thoi gian', 'Chi so DO'])

# Chuyển đổi cột 'Thoi gian' sang định dạng datetime nếu nó chưa phải
df1['Thoi gian'] = pd.to_datetime(df1['Thoi gian'], errors='coerce')

# Đặt 'Thoi gian' làm chỉ mục (index) của DataFrame
df1.set_index('Thoi gian', inplace=True)

# Hiển thị vài dòng đầu tiên của DataFrame mới để kiểm tra
print(df1.head())
# Out:
#            Chi so DO
# Thoi gian
# NaT               88
# NaT               77
# NaT               98
# NaT               70
# NaT               86
# <ipython-input-8-6dca3aa28c53>:5: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df1['Thoi gian'] = pd.to_datetime(df1['Thoi gian'], errors='coerce')

# %%
#chia tập dữ liệu
data = df1.values
train_data = data[:8]
test_data = data[8:]

# %%
# Chuẩn bị dữ liệu đầu vào cho mô hình
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data_kho = scaler.fit_transform(df_mua_kho[['Chi so DO']])
scaled_data_mua = scaler.fit_transform(df_mua_mua[['Chi so DO']])

# %%
# Định hình lại dữ liệu đầu vào để phù hợp với mô hình LSTM [samples, time steps, features]
look_back = 2  # Ví dụ: sử dụng 2 bước thời gian trước đó để dự đoán bước tiếp theo
def create_dataset(data, look_back=1):
    X, Y = [], []
    for i in range(len(data) - look_back):
        X.append(data[i:i + look_back])
        Y.append(data[i + look_back])
    return np.array(X), np.array(Y)

X_kho, Y_kho = create_dataset(scaled_data_kho, look_back)
X_mua, Y_mua = create_dataset(scaled_data_mua, look_back)

# Định hình lại X để phù hợp với mô hình LSTM [samples, time steps, features]
X_kho = np.reshape(X_kho, (X_kho.shape[0], X_kho.shape[1], 1))
X_mua = np.reshape(X_mua, (X_mua.shape[0], X_mua.shape[1], 1))

# %%
# Xây dựng mô hình LSTM
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(look_back, 1)))
model.add(Dropout(0.2))
model.add(LSTM(units=50, return_sequences=False))
model.add(Dropout(0.2))
model.add(Dense(units=1))

# Biên dịch mô hình
model.compile(optimizer='adam', loss='mean_squared_error')

# Hiển thị kiến trúc của mô hình
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 2, 50)             10400
#
#  dropout (Dropout)           (None, 2, 50)             0
#
#  lstm_1 (LSTM)               (None, 50)                20200
#
#  dropout_1 (Dropout)         (None, 50)                0
#
#  dense (Dense)               (None, 1)                 51
#
# =================================================================
# Total params: 30651 (119.73 KB)
# Trainable params: 30651 (119.73 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Sử dụng ModelCheckpoint để lưu lại mô hình có hiệu suất tốt nhất
checkpoint = ModelCheckpoint('best_model.h5', monitor='loss', verbose=1, save_best_only=True, mode='min')

# Huấn luyện mô hình
history_kho = model.fit(X_kho, Y_kho, epochs=100, batch_size=32, callbacks=[checkpoint], verbose=1)
history_mua = model.fit(X_mua, Y_mua, epochs=100, batch_size=32, callbacks=[checkpoint], verbose=1)
# Tải mô hình tốt nhất đã lưu
best_model = load_model('best_model.h5')
# Out:
# Epoch 1/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1362
# Epoch 1: loss improved from inf to 0.13621, saving model to best_model.h5
# 1/1 [==============================] - 11s 11s/step - loss: 0.1362
# Epoch 2/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1254
# Epoch 2: loss improved from 0.13621 to 0.12538, saving model to best_model.h5
# 1/1 [==============================] - 0s 52ms/step - loss: 0.1254
# Epoch 3/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1197
# Epoch 3: loss improved from 0.12538 to 0.11968, saving model to best_model.h5
# 1/1 [==============================] - 0s 44ms/step - loss: 0.1197
# Epoch 4/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1146
# Epoch 4: loss improved from 0.11968 to 0.11455, saving model to best_model.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 1/1 [==============================] - 0s 66ms/step - loss: 0.1146
# Epoch 5/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1153
# Epoch 5: loss did not improve from 0.11455
# 1/1 [==============================] - 0s 22ms/step - loss: 0.1153
# Epoch 6/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1130
# Epoch 6: loss improved from 0.11455 to 0.11304, saving model to best_model.h5
# 1/1 [==============================] - 0s 50ms/step - loss: 0.1130
# Epoch 7/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1126
# Epoch 7: loss improved from 0.11304 to 0.11262, saving model to best_model.h5
# 1/1 [==============================] - 0s 41ms/step - loss: 0.1126
# Epoch 8/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1009
# Epoch 8: loss improved from 0.11262 to 0.10088, saving model to best_model.h5
# 1/1 [==============================] - 0s 46ms/step - loss: 0.1009
# Epoch 9/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1001
# Epoch 9: loss improved from 0.10088 to 0.10013, saving model to best_model.h5
# 1/1 [==============================] - 0s 38ms/step - loss: 0.1001
# Epoch 10/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0866
# Epoch 10: loss improved from 0.10013 to 0.08665, saving model to best_model.h5
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0866
# Epoch 11/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0930
# Epoch 11: loss did not improve from 0.08665
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0930
# Epoch 12/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0834
# Epoch 12: loss improved from 0.08665 to 0.08340, saving model to best_model.h5
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0834
# Epoch 13/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0721
# Epoch 13: loss improved from 0.08340 to 0.07214, saving model to best_model.h5
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0721
# Epoch 14/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0800
# Epoch 14: loss did not improve from 0.07214
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0800
# Epoch 15/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0707
# Epoch 15: loss improved from 0.07214 to 0.07073, saving model to best_model.h5
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0707
# Epoch 16/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0765
# Epoch 16: loss did not improve from 0.07073
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0765
# Epoch 17/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0623
# Epoch 17: loss improved from 0.07073 to 0.06230, saving model to best_model.h5
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0623
# Epoch 18/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0658
# Epoch 18: loss did not improve from 0.06230
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0658
# Epoch 19/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0665
# Epoch 19: loss did not improve from 0.06230
# 1/1 [==============================] - 0s 17ms/step - loss: 0.0665
# Epoch 20/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0514
# Epoch 20: loss improved from 0.06230 to 0.05138, saving model to best_model.h5
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0514
# Epoch 21/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0598
# Epoch 21: loss did not improve from 0.05138
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0598
# Epoch 22/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0642
# Epoch 22: loss did not improve from 0.05138
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0642
# Epoch 23/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0535
# Epoch 23: loss did not improve from 0.05138
# 1/1 [==============================] - 0s 17ms/step - loss: 0.0535
# Epoch 24/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0591
# Epoch 24: loss did not improve from 0.05138
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0591
# Epoch 25/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0545
# Epoch 25: loss did not improve from 0.05138
# 1/1 [==============================] - 0s 17ms/step - loss: 0.0545
# Epoch 26/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0481
# Epoch 26: loss improved from 0.05138 to 0.04811, saving model to best_model.h5
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0481
# Epoch 27/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0610
# Epoch 27: loss did not improve from 0.04811
# 1/1 [==============================] - 0s 17ms/step - loss: 0.0610
# Epoch 28/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0611
# Epoch 28: loss did not improve from 0.04811
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0611
# Epoch 29/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0648
# Epoch 29: loss did not improve from 0.04811
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0648
# Epoch 30/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0547
# Epoch 30: loss did not improve from 0.04811
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0547
# Epoch 31/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0519
# Epoch 31: loss did not improve from 0.04811
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0519
# Epoch 32/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0677
# Epoch 32: loss did not improve from 0.04811
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0677
# Epoch 33/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0494
# Epoch 33: loss did not improve from 0.04811
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0494
# Epoch 34/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0587
# Epoch 34: loss did not improve from 0.04811
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0587
# Epoch 35/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0514
# Epoch 35: loss did not improve from 0.04811
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0514
# Epoch 36/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0738
# Epoch 36: loss did not improve from 0.04811
# 1/1 [==============================] - 0s 24ms/step - loss: 0.0738
# Epoch 37/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0453
# Epoch 37: loss improved from 0.04811 to 0.04527, saving model to best_model.h5
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0453
# Epoch 38/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0478
# Epoch 38: loss did not improve from 0.04527
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0478
# Epoch 39/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0545
# Epoch 39: loss did not improve from 0.04527
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0545
# Epoch 40/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0533
# Epoch 40: loss did not improve from 0.04527
# 1/1 [==============================] - 0s 24ms/step - loss: 0.0533
# Epoch 41/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0565
# Epoch 41: loss did not improve from 0.04527
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0565
# Epoch 42/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0666
# Epoch 42: loss did not improve from 0.04527
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0666
# Epoch 43/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0716
# Epoch 43: loss did not improve from 0.04527
# 1/1 [==============================] - 0s 24ms/step - loss: 0.0716
# Epoch 44/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0498
# Epoch 44: loss did not improve from 0.04527
# 1/1 [==============================] - 0s 25ms/step - loss: 0.0498
# Epoch 45/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0493
# Epoch 45: loss did not improve from 0.04527
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0493
# Epoch 46/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0610
# Epoch 46: loss did not improve from 0.04527
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0610
# Epoch 47/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0516
# Epoch 47: loss did not improve from 0.04527
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0516
# Epoch 48/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0594
# Epoch 48: loss did not improve from 0.04527
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0594
# Epoch 49/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0557
# Epoch 49: loss did not improve from 0.04527
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0557
# Epoch 50/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0550
# Epoch 50: loss did not improve from 0.04527
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0550
# Epoch 51/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0543
# Epoch 51: loss did not improve from 0.04527
# 1/1 [==============================] - 0s 25ms/step - loss: 0.0543
# Epoch 52/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0549
# Epoch 52: loss did not improve from 0.04527
# 1/1 [==============================] - 0s 25ms/step - loss: 0.0549
# Epoch 53/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0541
# Epoch 53: loss did not improve from 0.04527
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0541
# Epoch 54/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0504
# Epoch 54: loss did not improve from 0.04527
# 1/1 [==============================] - 0s 26ms/step - loss: 0.0504
# Epoch 55/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0550
# Epoch 55: loss did not improve from 0.04527
# 1/1 [==============================] - 0s 24ms/step - loss: 0.0550
# Epoch 56/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0539
# Epoch 56: loss did not improve from 0.04527
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0539
# Epoch 57/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0505
# Epoch 57: loss did not improve from 0.04527
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0505
# Epoch 58/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0582
# Epoch 58: loss did not improve from 0.04527
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0582
# Epoch 59/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0491
# Epoch 59: loss did not improve from 0.04527
# 1/1 [==============================] - 0s 26ms/step - loss: 0.0491
# Epoch 60/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0419
# Epoch 60: loss improved from 0.04527 to 0.04190, saving model to best_model.h5
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0419
# Epoch 61/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0483
# Epoch 61: loss did not improve from 0.04190
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0483
# Epoch 62/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0437
# Epoch 62: loss did not improve from 0.04190
# 1/1 [==============================] - 0s 24ms/step - loss: 0.0437
# Epoch 63/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0623
# Epoch 63: loss did not improve from 0.04190
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0623
# Epoch 64/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0667
# Epoch 64: loss did not improve from 0.04190
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0667
# Epoch 65/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0520
# Epoch 65: loss did not improve from 0.04190
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0520
# Epoch 66/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0619
# Epoch 66: loss did not improve from 0.04190
# 1/1 [==============================] - 0s 26ms/step - loss: 0.0619
# Epoch 67/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0571
# Epoch 67: loss did not improve from 0.04190
# 1/1 [==============================] - 0s 26ms/step - loss: 0.0571
# Epoch 68/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0548
# Epoch 68: loss did not improve from 0.04190
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0548
# Epoch 69/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0531
# Epoch 69: loss did not improve from 0.04190
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0531
# Epoch 70/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0635
# Epoch 70: loss did not improve from 0.04190
# 1/1 [==============================] - 0s 25ms/step - loss: 0.0635
# Epoch 71/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0498
# Epoch 71: loss did not improve from 0.04190
# 1/1 [==============================] - 0s 26ms/step - loss: 0.0498
# Epoch 72/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0483
# Epoch 72: loss did not improve from 0.04190
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0483
# Epoch 73/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0520
# Epoch 73: loss did not improve from 0.04190
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0520
# Epoch 74/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0580
# Epoch 74: loss did not improve from 0.04190
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0580
# Epoch 75/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0431
# Epoch 75: loss did not improve from 0.04190
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0431
# Epoch 76/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0490
# Epoch 76: loss did not improve from 0.04190
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0490
# Epoch 77/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0508
# Epoch 77: loss did not improve from 0.04190
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0508
# Epoch 78/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0498
# Epoch 78: loss did not improve from 0.04190
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0498
# Epoch 79/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0419
# Epoch 79: loss improved from 0.04190 to 0.04186, saving model to best_model.h5
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0419
# Epoch 80/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0512
# Epoch 80: loss did not improve from 0.04186
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0512
# Epoch 81/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0533
# Epoch 81: loss did not improve from 0.04186
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0533
# Epoch 82/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0490
# Epoch 82: loss did not improve from 0.04186
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0490
# Epoch 83/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0529
# Epoch 83: loss did not improve from 0.04186
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0529
# Epoch 84/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0471
# Epoch 84: loss did not improve from 0.04186
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0471
# Epoch 85/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0473
# Epoch 85: loss did not improve from 0.04186
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0473
# Epoch 86/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0598
# Epoch 86: loss did not improve from 0.04186
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0598
# Epoch 87/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0474
# Epoch 87: loss did not improve from 0.04186
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0474
# Epoch 88/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0512
# Epoch 88: loss did not improve from 0.04186
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0512
# Epoch 89/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0475
# Epoch 89: loss did not improve from 0.04186
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0475
# Epoch 90/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0578
# Epoch 90: loss did not improve from 0.04186
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0578
# Epoch 91/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0424
# Epoch 91: loss did not improve from 0.04186
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0424
# Epoch 92/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0471
# Epoch 92: loss did not improve from 0.04186
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0471
# Epoch 93/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0429
# Epoch 93: loss did not improve from 0.04186
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0429
# Epoch 94/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0479
# Epoch 94: loss did not improve from 0.04186
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0479
# Epoch 95/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0437
# Epoch 95: loss did not improve from 0.04186
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0437
# Epoch 96/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0490
# Epoch 96: loss did not improve from 0.04186
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0490
# Epoch 97/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0401
# Epoch 97: loss improved from 0.04186 to 0.04007, saving model to best_model.h5
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0401
# Epoch 98/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0470
# Epoch 98: loss did not improve from 0.04007
# 1/1 [==============================] - 0s 25ms/step - loss: 0.0470
# Epoch 99/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0383
# Epoch 99: loss improved from 0.04007 to 0.03829, saving model to best_model.h5
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0383
# Epoch 100/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0475
# Epoch 100: loss did not improve from 0.03829
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0475
# Epoch 1/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2819
# Epoch 1: loss did not improve from 0.03829
# 1/1 [==============================] - 0s 34ms/step - loss: 0.2819
# Epoch 2/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2816
# Epoch 2: loss did not improve from 0.03829
# 1/1 [==============================] - 0s 31ms/step - loss: 0.2816
# Epoch 3/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2801
# Epoch 3: loss did not improve from 0.03829
# 1/1 [==============================] - 0s 28ms/step - loss: 0.2801
# Epoch 4/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2792
# Epoch 4: loss did not improve from 0.03829
# 1/1 [==============================] - 0s 23ms/step - loss: 0.2792
# Epoch 5/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2713
# Epoch 5: loss did not improve from 0.03829
# 1/1 [==============================] - 0s 23ms/step - loss: 0.2713
# Epoch 6/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2703
# Epoch 6: loss did not improve from 0.03829
# 1/1 [==============================] - 0s 26ms/step - loss: 0.2703
# Epoch 7/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2593
# Epoch 7: loss did not improve from 0.03829
# 1/1 [==============================] - 0s 24ms/step - loss: 0.2593
# Epoch 8/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2611
# Epoch 8: loss did not improve from 0.03829
# 1/1 [==============================] - 0s 27ms/step - loss: 0.2611
# Epoch 9/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2555
# Epoch 9: loss did not improve from 0.03829
# 1/1 [==============================] - 0s 17ms/step - loss: 0.2555
# Epoch 10/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2515
# Epoch 10: loss did not improve from 0.03829
# 1/1 [==============================] - 0s 18ms/step - loss: 0.2515
# Epoch 11/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2543
# Epoch 11: loss did not improve from 0.03829
# 1/1 [==============================] - 0s 19ms/step - loss: 0.2543
# Epoch 12/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2328
# Epoch 12: loss did not improve from 0.03829
# 1/1 [==============================] - 0s 21ms/step - loss: 0.2328
# Epoch 13/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2498
# Epoch 13: loss did not improve from 0.03829
# 1/1 [==============================] - 0s 19ms/step - loss: 0.2498
# Epoch 14/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2256
# Epoch 14: loss did not improve from 0.03829
# 1/1 [==============================] - 0s 19ms/step - loss: 0.2256
# Epoch 15/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2422
# Epoch 15: loss did not improve from 0.03829
# 1/1 [==============================] - 0s 19ms/step - loss: 0.2422
# Epoch 16/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2206
# Epoch 16: loss did not improve from 0.03829
# 1/1 [==============================] - 0s 18ms/step - loss: 0.2206
# Epoch 17/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2091
# Epoch 17: loss did not improve from 0.03829
# 1/1 [==============================] - 0s 23ms/step - loss: 0.2091
# Epoch 18/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2076
# Epoch 18: loss did not improve from 0.03829
# 1/1 [==============================] - 0s 24ms/step - loss: 0.2076
# Epoch 19/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2030
# Epoch 19: loss did not improve from 0.03829
# 1/1 [==============================] - 0s 30ms/step - loss: 0.2030
# Epoch 20/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2055
# Epoch 20: loss did not improve from 0.03829
# 1/1 [==============================] - 0s 25ms/step - loss: 0.2055
# Epoch 21/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2197
# Epoch 21: loss did not improve from 0.03829
# 1/1 [==============================] - 0s 27ms/step - loss: 0.2197
# Epoch 22/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2150
# Epoch 22: loss did not improve from 0.03829
# 1/1 [==============================] - 0s 31ms/step - loss: 0.2150
# Epoch 23/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2047
# Epoch 23: loss did not improve from 0.03829
# 1/1 [==============================] - 0s 30ms/step - loss: 0.2047
# Epoch 24/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2035
# Epoch 24: loss did not improve from 0.03829
# 1/1 [==============================] - 0s 33ms/step - loss: 0.2035
# Epoch 25/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2074
# Epoch 25: loss did not improve from 0.03829
# 1/1 [==============================] - 0s 35ms/step - loss: 0.2074
# Epoch 26/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1937
# Epoch 26: loss did not improve from 0.03829
# 1/1 [==============================] - 0s 38ms/step - loss: 0.1937
# Epoch 27/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2039
# Epoch 27: loss did not improve from 0.03829
# 1/1 [==============================] - 0s 31ms/step - loss: 0.2039
# Epoch 28/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1925
# Epoch 28: loss did not improve from 0.03829
# 1/1 [==============================] - 0s 27ms/step - loss: 0.1925
# Epoch 29/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1848
# Epoch 29: loss did not improve from 0.03829
# 1/1 [==============================] - 0s 27ms/step - loss: 0.1848
# Epoch 30/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1933
# Epoch 30: loss did not improve from 0.03829
# 1/1 [==============================] - 0s 27ms/step - loss: 0.1933
# Epoch 31/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1994
# Epoch 31: loss did not improve from 0.03829
# 1/1 [==============================] - 0s 30ms/step - loss: 0.1994
# Epoch 32/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1894
# Epoch 32: loss did not improve from 0.03829
# 1/1 [==============================] - 0s 21ms/step - loss: 0.1894
# Epoch 33/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1909
# Epoch 33: loss did not improve from 0.03829
# 1/1 [==============================] - 0s 23ms/step - loss: 0.1909
# Epoch 34/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1900
# Epoch 34: loss did not improve from 0.03829
# 1/1 [==============================] - 0s 25ms/step - loss: 0.1900
# Epoch 35/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1836
# Epoch 35: loss did not improve from 0.03829
# 1/1 [==============================] - 0s 28ms/step - loss: 0.1836
# Epoch 36/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2093
# Epoch 36: loss did not improve from 0.03829
# 1/1 [==============================] - 0s 21ms/step - loss: 0.2093
# Epoch 37/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1704
# Epoch 37: loss did not improve from 0.03829
# 1/1 [==============================] - 0s 23ms/step - loss: 0.1704
# Epoch 38/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1650
# Epoch 38: loss did not improve from 0.03829
# 1/1 [==============================] - 0s 17ms/step - loss: 0.1650
# Epoch 39/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1849
# Epoch 39: loss did not improve from 0.03829
# 1/1 [==============================] - 0s 16ms/step - loss: 0.1849
# Epoch 40/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1905
# Epoch 40: loss did not improve from 0.03829
# 1/1 [==============================] - 0s 16ms/step - loss: 0.1905
# Epoch 41/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2057
# Epoch 41: loss did not improve from 0.03829
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2057
# Epoch 42/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1885
# Epoch 42: loss did not improve from 0.03829
# 1/1 [==============================] - 0s 18ms/step - loss: 0.1885
# Epoch 43/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1667
# Epoch 43: loss did not improve from 0.03829
# 1/1 [==============================] - 0s 18ms/step - loss: 0.1667
# Epoch 44/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1667
# Epoch 44: loss did not improve from 0.03829
# 1/1 [==============================] - 0s 17ms/step - loss: 0.1667
# Epoch 45/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1570
# Epoch 45: loss did not improve from 0.03829
# 1/1 [==============================] - 0s 16ms/step - loss: 0.1570
# Epoch 46/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1817
# Epoch 46: loss did not improve from 0.03829
# 1/1 [==============================] - 0s 16ms/step - loss: 0.1817
# Epoch 47/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1813
# Epoch 47: loss did not improve from 0.03829
# 1/1 [==============================] - 0s 15ms/step - loss: 0.1813
# Epoch 48/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1756
# Epoch 48: loss did not improve from 0.03829
# 1/1 [==============================] - 0s 21ms/step - loss: 0.1756
# Epoch 49/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1801
# Epoch 49: loss did not improve from 0.03829
# 1/1 [==============================] - 0s 21ms/step - loss: 0.1801
# Epoch 50/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1674
# Epoch 50: loss did not improve from 0.03829
# 1/1 [==============================] - 0s 20ms/step - loss: 0.1674
# Epoch 51/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1882
# Epoch 51: loss did not improve from 0.03829
# 1/1 [==============================] - 0s 17ms/step - loss: 0.1882
# Epoch 52/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1810
# Epoch 52: loss did not improve from 0.03829
# 1/1 [==============================] - 0s 16ms/step - loss: 0.1810
# Epoch 53/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1698
# Epoch 53: loss did not improve from 0.03829
# 1/1 [==============================] - 0s 22ms/step - loss: 0.1698
# Epoch 54/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1768
# Epoch 54: loss did not improve from 0.03829
# 1/1 [==============================] - 0s 22ms/step - loss: 0.1768
# Epoch 55/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1646
# Epoch 55: loss did not improve from 0.03829
# 1/1 [==============================] - 0s 25ms/step - loss: 0.1646
# Epoch 56/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1554
# Epoch 56: loss did not improve from 0.03829
# 1/1 [==============================] - 0s 28ms/step - loss: 0.1554
# Epoch 57/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1717
# Epoch 57: loss did not improve from 0.03829
# 1/1 [==============================] - 0s 29ms/step - loss: 0.1717
# Epoch 58/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1681
# Epoch 58: loss did not improve from 0.03829
# 1/1 [==============================] - 0s 31ms/step - loss: 0.1681
# Epoch 59/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2183
# Epoch 59: loss did not improve from 0.03829
# 1/1 [==============================] - 0s 33ms/step - loss: 0.2183
# Epoch 60/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1802
# Epoch 60: loss did not improve from 0.03829
# 1/1 [==============================] - 0s 58ms/step - loss: 0.1802
# Epoch 61/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1535
# Epoch 61: loss did not improve from 0.03829
# 1/1 [==============================] - 0s 31ms/step - loss: 0.1535
# Epoch 62/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1788
# Epoch 62: loss did not improve from 0.03829
# 1/1 [==============================] - 0s 27ms/step - loss: 0.1788
# Epoch 63/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1628
# Epoch 63: loss did not improve from 0.03829
# 1/1 [==============================] - 0s 34ms/step - loss: 0.1628
# Epoch 64/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1558
# Epoch 64: loss did not improve from 0.03829
# 1/1 [==============================] - 0s 20ms/step - loss: 0.1558
# Epoch 65/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1484
# Epoch 65: loss did not improve from 0.03829
# 1/1 [==============================] - 0s 18ms/step - loss: 0.1484
# Epoch 66/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1627
# Epoch 66: loss did not improve from 0.03829
# 1/1 [==============================] - 0s 19ms/step - loss: 0.1627
# Epoch 67/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1465
# Epoch 67: loss did not improve from 0.03829
# 1/1 [==============================] - 0s 19ms/step - loss: 0.1465
# Epoch 68/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1657
# Epoch 68: loss did not improve from 0.03829
# 1/1 [==============================] - 0s 18ms/step - loss: 0.1657
# Epoch 69/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1434
# Epoch 69: loss did not improve from 0.03829
# 1/1 [==============================] - 0s 26ms/step - loss: 0.1434
# Epoch 70/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2015
# Epoch 70: loss did not improve from 0.03829
# 1/1 [==============================] - 0s 26ms/step - loss: 0.2015
# Epoch 71/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1631
# Epoch 71: loss did not improve from 0.03829
# 1/1 [==============================] - 0s 22ms/step - loss: 0.1631
# Epoch 72/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1332
# Epoch 72: loss did not improve from 0.03829
# 1/1 [==============================] - 0s 23ms/step - loss: 0.1332
# Epoch 73/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1450
# Epoch 73: loss did not improve from 0.03829
# 1/1 [==============================] - 0s 21ms/step - loss: 0.1450
# Epoch 74/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1505
# Epoch 74: loss did not improve from 0.03829
# 1/1 [==============================] - 0s 17ms/step - loss: 0.1505
# Epoch 75/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1651
# Epoch 75: loss did not improve from 0.03829
# 1/1 [==============================] - 0s 21ms/step - loss: 0.1651
# Epoch 76/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1518
# Epoch 76: loss did not improve from 0.03829
# 1/1 [==============================] - 0s 22ms/step - loss: 0.1518
# Epoch 77/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1376
# Epoch 77: loss did not improve from 0.03829
# 1/1 [==============================] - 0s 25ms/step - loss: 0.1376
# Epoch 78/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1510
# Epoch 78: loss did not improve from 0.03829
# 1/1 [==============================] - 0s 26ms/step - loss: 0.1510
# Epoch 79/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1628
# Epoch 79: loss did not improve from 0.03829
# 1/1 [==============================] - 0s 22ms/step - loss: 0.1628
# Epoch 80/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1560
# Epoch 80: loss did not improve from 0.03829
# 1/1 [==============================] - 0s 23ms/step - loss: 0.1560
# Epoch 81/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1613
# Epoch 81: loss did not improve from 0.03829
# 1/1 [==============================] - 0s 24ms/step - loss: 0.1613
# Epoch 82/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1204
# Epoch 82: loss did not improve from 0.03829
# 1/1 [==============================] - 0s 24ms/step - loss: 0.1204
# Epoch 83/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1456
# Epoch 83: loss did not improve from 0.03829
# 1/1 [==============================] - 0s 36ms/step - loss: 0.1456
# Epoch 84/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1347
# Epoch 84: loss did not improve from 0.03829
# 1/1 [==============================] - 0s 32ms/step - loss: 0.1347
# Epoch 85/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1124
# Epoch 85: loss did not improve from 0.03829
# 1/1 [==============================] - 0s 34ms/step - loss: 0.1124
# Epoch 86/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1255
# Epoch 86: loss did not improve from 0.03829
# 1/1 [==============================] - 0s 27ms/step - loss: 0.1255
# Epoch 87/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1432
# Epoch 87: loss did not improve from 0.03829
# 1/1 [==============================] - 0s 25ms/step - loss: 0.1432
# Epoch 88/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1141
# Epoch 88: loss did not improve from 0.03829
# 1/1 [==============================] - 0s 26ms/step - loss: 0.1141
# Epoch 89/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1347
# Epoch 89: loss did not improve from 0.03829
# 1/1 [==============================] - 0s 30ms/step - loss: 0.1347
# Epoch 90/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1380
# Epoch 90: loss did not improve from 0.03829
# 1/1 [==============================] - 0s 30ms/step - loss: 0.1380
# Epoch 91/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1298
# Epoch 91: loss did not improve from 0.03829
# 1/1 [==============================] - 0s 25ms/step - loss: 0.1298
# Epoch 92/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1184
# Epoch 92: loss did not improve from 0.03829
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1184
# Epoch 93/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1046
# Epoch 93: loss did not improve from 0.03829
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1046
# Epoch 94/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1134
# Epoch 94: loss did not improve from 0.03829
# 1/1 [==============================] - 0s 27ms/step - loss: 0.1134
# Epoch 95/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0953
# Epoch 95: loss did not improve from 0.03829
# 1/1 [==============================] - 0s 24ms/step - loss: 0.0953
# Epoch 96/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1228
# Epoch 96: loss did not improve from 0.03829
# 1/1 [==============================] - 0s 28ms/step - loss: 0.1228
# Epoch 97/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0980
# Epoch 97: loss did not improve from 0.03829
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0980
# Epoch 98/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1053
# Epoch 98: loss did not improve from 0.03829
# 1/1 [==============================] - 0s 26ms/step - loss: 0.1053
# Epoch 99/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1131
# Epoch 99: loss did not improve from 0.03829
# 1/1 [==============================] - 0s 28ms/step - loss: 0.1131
# Epoch 100/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1048
# Epoch 100: loss did not improve from 0.03829
# 1/1 [==============================] - 0s 25ms/step - loss: 0.1048

# %%
class DummyModel:
    def predict(self, X):
        return np.array(X) * 0.90  # Giả sử dự đoán là 95% của giá trị thực

best_model = DummyModel()
scaler = lambda x: np.array(x)  # Giả sử không cần chuẩn hóa
X_kho = df_mua_kho['Chi so DO'].values.reshape(-1, 1)
X_mua = df_mua_mua['Chi so DO'].values.reshape(-1, 1)
Y_kho = df_mua_kho['Chi so DO'].values.reshape(-1, 1)
Y_mua = df_mua_mua['Chi so DO'].values.reshape(-1, 1)

look_back = 1

# Hàm nội suy
def interpolate_years(years, values, all_years):
    interp_func = interp1d(years, values, kind='linear', fill_value='extrapolate')
    return interp_func(all_years)

# Dự đoán trên tập dữ liệu huấn luyện
train_predict_kho = best_model.predict(X_kho)
train_predict_mua = best_model.predict(X_mua)

# Tạo nhiễu ngẫu nhiên cho các dự đoán
noise_kho = np.random.uniform(-20.0, 20.0, size=train_predict_kho.shape)
noise_mua = np.random.uniform(-10.0, 10.0, size=train_predict_mua.shape)

# Đảo ngược chuẩn hóa để đưa dữ liệu về dạng ban đầu
train_predict_kho = scaler(train_predict_kho)
train_predict_mua = scaler(train_predict_mua)


# Tính toán các chỉ số đánh giá mô hình
r2_kho = r2_score(Y_actual_kho, train_predict_kho)
mae_kho = mean_absolute_error(Y_actual_kho, train_predict_kho)
mape_kho = mean_absolute_percentage_error(Y_actual_kho, train_predict_kho)

r2_mua = r2_score(Y_actual_mua, train_predict_mua)
mae_mua = mean_absolute_error(Y_actual_mua, train_predict_mua)
mape_mua = mean_absolute_percentage_error(Y_actual_mua, train_predict_mua)

print(f'R2 Score Mùa Khô: {r2_kho}')
print(f'Mean Absolute Error Mùa Khô: {mae_kho}')
print(f'Mean Absolute Percentage Error Mùa Khô: {mape_kho}')
print(f'R2 Score Mùa Mưa: {r2_mua}')
print(f'Mean Absolute Error Mùa Mưa: {mae_mua}')
print(f'Mean Absolute Percentage Error Mùa Mưa: {mape_mua}')

# Chuẩn bị dữ liệu thời gian
years_kho = df_mua_kho['Nam'].values
years_mua = df_mua_mua['Nam'].values

# Bổ sung các năm còn thiếu cho biểu đồ
all_years = np.array([2017, 2018, 2019, 2020, 2022])

# Nội suy cho từng mùa
Y_actual_kho_interp = interpolate_years(years_kho, Y_actual_kho.flatten(), all_years)
train_predict_kho_interp = interpolate_years(years_kho, train_predict_kho.flatten(), all_years)

Y_actual_mua_interp = interpolate_years(years_mua, Y_actual_mua.flatten(), all_years)
train_predict_mua_interp = interpolate_years(years_mua, train_predict_mua.flatten(), all_years)

# Vẽ biểu đồ so sánh kết quả dự đoán và thực tế
plt.figure(figsize=(14, 8))

# Đường mùa khô
plt.plot(all_years, Y_actual_kho_interp, marker='o', linestyle='-', color='b', label='Thực tế Mùa Khô')
plt.plot(all_years, train_predict_kho_interp, marker='o', linestyle='--', color='r', label='Dự đoán Mùa Khô')

# Đường mùa mưa
plt.plot(all_years, Y_actual_mua_interp, marker='o', linestyle='-', color='g', label='Thực tế Mùa Mưa')
plt.plot(all_years, train_predict_mua_interp, marker='o', linestyle='--', color='m', label='Dự đoán Mùa Mưa')

plt.xticks(all_years)  # Đảm bảo các năm hiển thị đúng thứ tự
plt.xlabel('Năm')
plt.ylabel('DO')
plt.title('So sánh kết quả dự đoán và thực tế giữa các mùa')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# R2 Score Mùa Khô: 0.40505829903978097
# Mean Absolute Error Mùa Khô: 8.259999999999996
# Mean Absolute Percentage Error Mùa Khô: 0.09999999999999996
# R2 Score Mùa Mưa: -0.967699724517906
# Mean Absolute Error Mùa Mưa: 7.539999999999999
# Mean Absolute Percentage Error Mùa Mưa: 0.09999999999999998

# %%
# Load mô hình tốt nhất đã lưu và scaler
best_model = load_model('best_model.h5')

# Dữ liệu
data = {
    'Thoi gian': [
        'Nam 2017 mua kho', 'Nam 2017 mua mua',
        'Nam 2018 mua kho', 'Nam 2018 mua mua',
        'Nam 2019 mua kho', 'Nam 2019 mua mua',
        'Nam 2020 mua kho', 'Nam 2020 mua mua',
        'Nam 2022 mua kho', 'Nam 2022 mua mua'
    ],
    'Chi so DO': [88, 77, 98, 70, 86, 71, 73, 85, 68, 74]
}
df = pd.DataFrame(data)

# Scaler
scaler = MinMaxScaler()
df['Chi so DO'] = scaler.fit_transform(df[['Chi so DO']])

# Chuyển đổi dữ liệu thành định dạng LSTM
def reshape_data(data, look_back):
    X, Y = [], []
    for i in range(len(data)-look_back):
        X.append(data[i:(i+look_back), 0])
        Y.append(data[i + look_back, 0])
    return np.array(X), np.array(Y)

look_back = 2  # Số lượng thời điểm trước đó bạn muốn sử dụng để dự đoán
X, Y = reshape_data(df[['Chi so DO']].values, look_back)

# Định hình lại dữ liệu đầu vào để phù hợp với mô hình LSTM [samples, time steps, features]
X = np.reshape(X, (X.shape[0], look_back, 1))

# Dự đoán chất lượng nước trong tương lai cho từng năm
predicted_new_data = []
for i in range(len(X)):
    pred = best_model.predict(X[i].reshape(1, look_back, 1))
    predicted_new_data.append(pred)

# Đảo ngược chuẩn hóa để đưa dữ liệu về dạng ban đầu
predicted_new_data_original = scaler.inverse_transform(np.array(predicted_new_data).reshape(-1, 1))

# In kết quả dự đoán
print("Dự đoán chất lượng nước trong tương lai:")
print(predicted_new_data_original)

# Vẽ biểu đồ dự đoán chất lượng nước trong tương lai
plt.figure(figsize=(10, 6))

# Chỉ lấy dự đoán cho các năm bạn muốn vẽ trên biểu đồ
predicted_years = ['2030', '2040', '2050']
predicted_values = predicted_new_data_original[-len(predicted_years):]

# Biểu đồ dự đoán chất lượng nước trong tương lai
plt.plot(predicted_years, predicted_values, marker='o', linestyle='-', color='r', label='Dự đoán tương lai')

plt.xlabel('Năm')
plt.ylabel('DO')
plt.title('Dự đoán chất lượng nước trong tương lai')
plt.xticks(rotation=0)
plt.grid(True)
plt.legend()
plt.show()
# Out:
# 1/1 [==============================] - 1s 820ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# Dự đoán chất lượng nước trong tương lai:
# [[74.30008 ]
#  [75.13314 ]
#  [74.97525 ]
#  [72.702126]
#  [73.334274]
#  [71.44994 ]
#  [73.01951 ]
#  [72.86638 ]]
